# %% [markdown]
# Fordi K'(t)=k'K(t) der k=0.05 gir at veksten per måned er fem prosent av befolkningen. Initialbetingelsen er K(0)=100

# %%
from pylab import *

h=1E-2
N=int(12/h)
y=zeros(N)
k=0.05
x=zeros(N)
y[0]=200
def yder(y,x):
    return k*y

for i in range(N-1):
    y[i+1]=y[i]+yder(y[i],x[i])*h
    x[i+1]=x[i]+h

plot(x,y)
grid('True')
# Out:
# C:\Users\sverr\Anaconda3\lib\site-packages\matplotlib\cbook\deprecation.py:107: MatplotlibDeprecationWarning: Passing one of 'on', 'true', 'off', 'false' as a boolean is deprecated; use an actual boolean (True/False) instead.
#   warnings.warn(message, mplDeprecation, stacklevel=1)

# %% [markdown]
# Veksten er eksponensiell. Hvis vi endrer initialetingelsene blir forholdet mellom veksten likt som forholdet mellom initialbetingelsene. Kaniner sluppet introdusert til Australia hadde en vekst på 19%. Hvis den øker med ti eller femti prosent stiger den raskere i forhold til initialbetingelsene. Hvis man skal angi t i år må man endre k for at veksten skal bli lik.
#
# K kan skrives K(t)=C*e^k*t

# %% [markdown]
# 2
# B(0) blir 5000
# bæreevnen er antall individer som kan holdes i live av habitatet. Den bestemmes av tilgjengelighet på mat og plass for å unngå sykdommer og andre problemer som kommer med en for tett befolkning.
#
# B'(t)=k*B(t)*(1-B(t)/b)

# %%
from pylab import *

h=1E-2
N=int(36/h)
y=zeros(N)
k=0.18
x=zeros(N)
y[0]=5000
b=50000
def yder(y,x):
    return k*y*(1-y/b)

for i in range(N-1):
    y[i+1]=y[i]+yder(y[i],x[i])*h
    x[i+1]=x[i]+h

plot(x,y)
grid('True')
# Out:
# C:\Users\sverr\Anaconda3\lib\site-packages\matplotlib\cbook\deprecation.py:107: MatplotlibDeprecationWarning: Passing one of 'on', 'true', 'off', 'false' as a boolean is deprecated; use an actual boolean (True/False) instead.
#   warnings.warn(message, mplDeprecation, stacklevel=1)

# %% [markdown]
# Det skal ikke være k=0.000004 men k=0.18
# 900/5000=0.18

# %%
from pylab import *

h=1E-2
N=int(36/h)
R=zeros(N)
B=zeros(N)
x=zeros(N)
B[0]=100
R[0]=100
a=0.25
b=0.002
c=0.1
d=0.001

def Rder(R,x,B):
    return c*B*R-d*R
def Bder(R,x,B):
    a*B-b*B*R

for i in range(N-1):
    B[i+1]=B[i]+Bder(R[i],x[i],B[i])*h
    R[i+1]=R[i]+Rder(R[i],x[i],B[i])*h
    x[i+1]=x[i]+h

plot(x,B)
plot(x,R)
grid('True')
